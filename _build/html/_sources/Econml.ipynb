# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyreadstat
import re
import string
import sklearn
from sklearn_pandas import DataFrameMapper
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, LogisticRegression,LogisticRegressionCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR


from tqdm import tqdm_notebook as tqdm
from reed import *
#from cinspect import dependence, importance
from sklearn.model_selection import cross_val_score, cross_validate

from econml.orf import DMLOrthoForest, DROrthoForest
from econml.dml import CausalForestDML
from econml.sklearn_extensions.linear_model import WeightedLassoCVWrapper, WeightedLasso, WeightedLassoCV
from sklearn.linear_model import LogisticRegression, Lasso


# set global notebook options
pd.options.display.max_columns = 200
pd.options.display.max_rows = 500
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

import logging.config
DEFAULT_LOGGING = {
    'version': 1,
    'disable_existing_loggers': False,
    'loggers': {
        '': {
            'level': 'INFO',
        },
    }
}

logging.config.dictConfig(DEFAULT_LOGGING)

# %% [markdown]
# # Load the data

# %%
outcome = 'y_Dwsce'#'y_wsce'
treatment = 'redufl'
optimisation_metric = 'neg_mean_squared_error'
evaluation_metrics = ('r2','neg_mean_squared_error')
log_outcome=False
data_file = "all_vars.csv"

# %%
data = pd.read_csv(data_file,index_col='xwaveid')
drop_missing_treatment_or_outcome(data, treatment, outcome)
if log_outcome:
    data[outcome] = np.log(data[outcome]+data[outcome].min())
# Out:
# Dropped 592 rows missing treatment or outcome.

# %% [markdown]
# ### Prepare data for modeling

# %%
from direct_regression import seperate_and_transform_data
X0, X1, y0, y1, X, y, T, features = seperate_and_transform_data(data, treatment, outcome)

print("Control data dimensions: ",X0.shape)
print("Treated data dimensions:",X1.shape)
# Out:
# Control data dimensions:  (3659, 638)
# Treated data dimensions: (1295, 638)

# %% [markdown]
# ### Basic check on E[Y] and E[Y|T]

# %%
from direct_regression import print_unconditional_effects
print_unconditional_effects(data, treatment, y0, y1)
# Out:
# Proportion Treated:26%
# Average outcome under Control:67.85±15.36
# Average outcome under Treatment:310.57±29.39
# Unadjusted treatment estimate 242.72

# %% [markdown]
# ### Separate covariates X into Xh and W
#
# EconML requires `X` (covariates with which to compute heterogeneity) to be set, even if you only want to estimate ATE.
#
# We will use `Xh` for the covariates passed to $X$ for EconML and `W` for the remaining variables ie `Union(Xh, W) = X`
#
# For initial testing, lets just take the feature with the largest coefficient to be the one to compute CATE with respect to.

# %%
def find_most_predictive_feature(X,T,y,features):
    model = Lasso()
    V = np.hstack((X,T.reshape(-1,1)))
    features_ext = features + ['treatment']
    model.fit(V,y)
    coef = pd.DataFrame({"coef":model.coef_},index=features_ext)
    coef['magnitude'] = coef['coef'].abs()
    coef_mag = coef.sort_values('magnitude',ascending=False)  
    return coef_mag

coef_mag = find_most_predictive_feature(X,T,y,features)
coef_mag.head(3)
# Out:
#                 coef   magnitude
# awscmei  -377.779591  377.779591
# ahgage   -352.846828  352.846828
# ahiwsfei  119.712270  119.712270

# %%
hetero_feature = coef_mag.iloc[0].name
print(f"Computing treatment effect heterogeneity with respect to: {hetero_feature}")
x_indx = features.index(hetero_feature)
Xh = X[:,x_indx].reshape(-1,1) # X for EconML models
W = np.delete(X,x_indx, axis=1)
# Out:
# Computing treatment effect heterogeneity with respect to: awscmei

# %% [markdown]
# ### LinearDML

# %%
from econml.dml import LinearDML
ldml = LinearDML(discrete_treatment=True)
ldml.fit(y,T,X=Xh,W=W)
# Out:
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# Objective did not converge. You might want to increase the number of iterations. Duality gap:
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2118570.1545892954, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2597844.6643561125, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2579239.0858380795, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1848615.7801482677, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2643642.132882476, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 4722787.870781839, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 5464124.565022707, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1829055.8724102378, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1728578.1009181738, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1928001.5088040233, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2518587.2368767858, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3870665.406595707, tolerance: 210248.31160771937
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 4654514.850140452, tolerance: 210248.31160771937
# 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 285641.3469978571, tolerance: 174963.6226200908
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 556682.4322345257, tolerance: 174963.6226200908
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 607658.6083658934, tolerance: 174963.6226200908
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 702476.1212161183, tolerance: 174963.6226200908
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 847160.7584556341, tolerance: 174963.6226200908
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 176422.63526898623, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 186488.8738449812, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 262353.62865817547, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 193537.99712324142, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 232120.77226018906, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 527393.9928199053, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 479306.02039408684, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 438980.68373835087, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 414196.7036269307, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 552048.6909204721, tolerance: 171916.08191499257
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 267165.9323345423, tolerance: 169897.58458753783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 215679.1718441248, tolerance: 169897.58458753783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 205662.5749115944, tolerance: 169897.58458753783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 257920.26911485195, tolerance: 169897.58458753783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 680198.0100538731, tolerance: 169897.58458753783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 791568.5677028894, tolerance: 169897.58458753783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 881324.9144995213, tolerance: 169897.58458753783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 893965.3098157644, tolerance: 169897.58458753783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 952724.5011513233, tolerance: 169897.58458753783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 214924.2612001896, tolerance: 182802.9958750757
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 712742.693831563, tolerance: 182802.9958750757
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1052822.7012194395, tolerance: 182802.9958750757
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 380247.90730655193, tolerance: 182802.9958750757
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 280498.57795745134, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 712264.0454063416, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 822740.6380782723, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 880122.1159847975, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 958892.5986293554, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 950872.912407279, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 996918.385838747, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 714288.0288088918, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 560663.5440487266, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 431511.64100575447, tolerance: 180907.87586700296
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 427697.92236065865, tolerance: 180907.87586700296
# 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.

# %%
ldml.ate(X=Xh), ldml.ate_interval(X=Xh)
# Out:
# (62.45811603051127, (6.17173847174513, 118.7444935892774))

# %%
from econml.dml import SparseLinearDML
sldml = SparseLinearDML(discrete_treatment=True)
sldml.fit(y,T,X=Xh,W=W)

# %%
sldml.ate(X=Xh), ldml.ate_interval(X=Xh)

# %% [markdown]
# ### LinearDR Learner

# %%
from econml.dr import LinearDRLearner
ldr = LinearDRLearner()
ldr.fit(y,T,X=Xh,W=W)

# %%
ldr.ate(X=Xh), ldr.ate_interval(X=Xh)

# %% [markdown]
# ### CausalForestDML

# %%
from econml.dml import CausalForestDML
cf = CausalForestDML(model_y=Lasso(),
                       model_t=LogisticRegression(),
                       discrete_treatment=True,
                       random_state=123)
cf.fit(y, T, X=Xh, W=W)

# %%
cf.ate(X=Xh), cf.ate_interval(X=Xh)

# %% [markdown]
# ### Meta Learners

# %%
from econml.metalearners import TLearner, SLearner, XLearner, DomainAdaptationLearner
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Lasso

# %%
models = LassoCV(alphas=np.logspace(-2,4,30),max_iter=5000)
est_t = TLearner(models=models)
est_t.fit(y, T, X=X, inference='bootstrap')
# Out:
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 497055.3242598772, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 156213.37949693203, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 159778.52901130915, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 174565.7763695717, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 240431.79050028324, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 682902.4319127798, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 310851.04122006893, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 261663.36314463615, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 351626.9860777855, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 717677.0553798676, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 693280.8380118608, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 697459.3041567802, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 783923.4491571784, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 826435.0735100508, tolerance: 114245.4763408301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 123436.06948041916, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 129521.94764208794, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 117088.146089077, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 109988.56475436687, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 162589.33761113882, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 212323.4153881073, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 180722.45394790173, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 233444.8443479538, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 892924.3317566514, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2219870.90666312, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3789970.3967097998, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 4711002.074768722, tolerance: 108254.72814169887
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 175008.0419269204, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 212667.56175208092, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 463622.0950063467, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 626035.5825657845, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 817840.324169755, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 677837.7911307216, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 632242.1738643646, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 631894.7457575798, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 643575.8175595999, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 657550.1895372868, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 660841.0398131609, tolerance: 112833.83280115829
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 182744.23535978794, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 342048.57532566786, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 377329.55474066734, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 356542.6639484167, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 304730.32365095615, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 323802.2190285921, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 349172.7601289749, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 314790.7893307209, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 325688.56614375114, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 333650.70942914486, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 329213.22197186947, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 297617.48459386826, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 257656.15457832813, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 382351.2557116747, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1254328.8794385195, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730169.2368381023, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 280984.8440234661, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 250324.51379787922, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 231269.9275122881, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 238385.69654023647, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 828669.1088634729, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2178797.707190275, tolerance: 117794.30310608109
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 144573.5310086012, tolerance: 126215.42409575291
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 152217.82304686308, tolerance: 126215.42409575291
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 150769.79483819008, tolerance: 126215.42409575291
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 173577.6185696125, tolerance: 126215.42409575291
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 148430.02874743938, tolerance: 126215.42409575291
# Objective did not converge. You might want to increase the number of iterations. Duality gap:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_59867/1313162946.py in <module>
#       1 models = LassoCV()
#       2 est_t = TLearner(models=models)
# ----> 3 est_t.fit(y, T, X=X, inference='bootstrap')
#       4 est_t.ate(X=X), est_t.ate_interval(X=X)
#
# ~/miniconda3/envs/reed/lib/python3.9/site-packages/econml/_cate_estimator.py in call(self, Y, T, inference, *args, **kwargs)
#     132             if inference is not None:
#     133                 # NOTE: we call inference fit *after* calling the main fit method
# --> 134                 inference.fit(self, Y, T, *args, **kwargs)
#     135             self._inference = inference
#     136             return self
#
# ~/miniconda3/envs/reed/lib/python3.9/site-packages/econml/inference/_inference.py in fit(self, estimator, *args, **kwargs)
#      90                                  bootstrap_type=self._bootstrap_type, verbose=self._verbose)
#      91         filtered_kwargs = filter_none_kwargs(**kwargs)
# ---> 92         est.fit(*args, **filtered_kwargs)
#      93         self._est = est
#      94         self._d_t = estimator._d_t
#
# ~/miniconda3/envs/reed/lib/python3.9/site-packages/econml/inference/_bootstrap.py in fit(self, *args, **named_args)
#     119                 return arg
#     120
# --> 121         self._instances = Parallel(n_jobs=self._n_jobs, prefer='threads', verbose=self._verbose)(
#     122             delayed(fit)(obj,
#     123                          *[convertArg(arg, inds) for arg in args],
#
# ~/miniconda3/envs/reed/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/envs/reed/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~/miniconda3/envs/reed/lib/python3.9/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/miniconda3/envs/reed/lib/python3.9/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/miniconda3/envs/reed/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# ~/miniconda3/envs/reed/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
LassoCV?

# %%
est_t.ate(X=X), est_t.ate_interval(X=X)

# %% [markdown]
# #### GradientBoosting

# %%
models = GradientBoostingRegressor()
est_t2 = TLearner(models=models)
est_t2.fit(y, T, X=X, inference='bootstrap')

# %%
est_t2.ate(X=X), est_t2.ate_interval(X=X)

# %%
# TODO - figure out how to set the number of bootstrap samples
# TODO - implement manual bootstrapping
# TODO - plot CATE
# TODO - figure out why we have to set X (look at the implementation in EconML)
# TODO - test out some other implementations of DoubleML/CausalForest (maybe in R)
# TODO - look at cricism methods on do-why and test them out (see if we can get the same results through the do-why interface)
